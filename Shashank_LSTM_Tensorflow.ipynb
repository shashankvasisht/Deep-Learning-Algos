# %%
import tensorflow as tf
import numpy as np
import os

# %%
data_dir = '/home/shashank/Desktop/BootcampStudents/Data/Task_1/'
batch_size = 32

# %%
data = np.load(os.path.join(data_dir,'LSTM.npz'))
train_x,train_y = data["train_x"],data['train_y']
val_x,val_y = data['val_x'],data['val_y']
test_x,test_y = data['test_x'],data['test_y']
print train_x.shape,' ',train_y.shape
# Out:
# (588, 50, 2048)   (588, 5)

# %%
def next_batch(batch_number):
    tr_x_batch  = train_x[batch_number*batch_size:(batch_number+1)*batch_size]
    tr_y_batch = train_y[batch_number*batch_size:(batch_number+1)*batch_size]
    return tr_x_batch,tr_y_batch

# %%
x_pl = tf.placeholder(tf.float32,shape=[None,50,2048])
y_pl = tf.placeholder(tf.float32,shape=[None,5])

# %%
neur_rnn = 128
cell = tf.nn.rnn_cell.LSTMCell(neur_rnn)
outputs,_ = tf.nn.dynamic_rnn(cell,x_pl,dtype=tf.float32)

# %%
outputs_flattened = tf.reshape(outputs,[-1,50*neur_rnn])
print outputs_flattened.shape
# Out:
# (?, 6400)

# %%
def Weight_Variable(shape):
    initial = tf.random_normal(shape,mean=0,stddev=1/np.sqrt(50*neur_rnn))
    return tf.Variable(initial)

# %%
def Bias_Variable(shape):
    initial = tf.constant(0.1,shape=shape)
    return tf.Variable(initial)

# %%
W_1 = Weight_Variable([50*neur_rnn,128])
B_1 = Bias_Variable([128])

# %%
h_1 = tf.nn.leaky_relu(tf.matmul(outputs_flattened,W_1)+B_1)

# %%
W_2 = Weight_Variable([128,5])
B_2 = Bias_Variable([5])

# %%
y_conv = tf.matmul(h_1,W_2)+B_2

# %%
cross_entropy = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=y_pl, logits=y_conv))

train_step = tf.train.GradientDescentOptimizer(1e-3).minimize(cross_entropy)

# %%
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_pl, 1))

accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
max_epochs = 100
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for ex in range(max_epochs):
        i=0
        print "epoch_no :",ex
        print '------------------------'
        while True:
            tr_x_batch,tr_y_batch = next_batch(i)
            train_step.run(feed_dict={x_pl:tr_x_batch,y_pl:tr_y_batch})
            
            if (tr_x_batch.shape[0]!=32):
                break
            i += 1
        train_accuracy = accuracy.eval(feed_dict={x_pl:train_x,y_pl:train_y})
        print ' training accuracy:', train_accuracy
        
        test_accuracy = accuracy.eval(feed_dict={x_pl:test_x,y_pl:test_y})
        print ' test accuracy:',test_accuracy
        print'----------------------------'
#         while True:
#             tr_x_batch,tr_y_batch = next_batch(i)
#             test_accuracy += accuracy.eval(feed_dict={x_pl:tr_x_batch,y_pl:tr_y_batch})
#             if (tr_x_batch.shape[0]!=32):
#                 break
#         test_accuracy /= tr_x_batch.shape[0]
#         print ' test accuracy:', test_accuracy
        
        
        #test_accuracy = accuracy.eval(feed_dict={x_pl:test_x,y_pl:test_y})
# Out:
# epoch_no : 0
# ------------------------
#  training accuracy: 0.215986
#  test accuracy: 0.153846
# ----------------------------
# epoch_no : 1
# ------------------------
#  training accuracy: 0.289116
#  test accuracy: 0.230769
# ----------------------------
# epoch_no : 2
# ------------------------
#  training accuracy: 0.306122
#  test accuracy: 0.296703
# ----------------------------
# epoch_no : 3
# ------------------------
#  training accuracy: 0.338435
#  test accuracy: 0.307692
# ----------------------------
# epoch_no : 4
# ------------------------
#  training accuracy: 0.392857
#  test accuracy: 0.340659
# ----------------------------
# epoch_no : 5
# ------------------------
#  training accuracy: 0.454082
#  test accuracy: 0.351648
# ----------------------------
# epoch_no : 6
# ------------------------
#  training accuracy: 0.510204
#  test accuracy: 0.362637
# ----------------------------
# epoch_no : 7
# ------------------------
#  training accuracy: 0.52551
#  test accuracy: 0.351648
# ----------------------------
# epoch_no : 8
# ------------------------
#  training accuracy: 0.547619
#  test accuracy: 0.351648
# ----------------------------
# epoch_no : 9
# ------------------------
#  training accuracy: 0.557823
#  test accuracy: 0.351648
# ----------------------------
# epoch_no : 10
# ------------------------
#  training accuracy: 0.568027
#  test accuracy: 0.362637
# ----------------------------
# epoch_no : 11
# ------------------------
#  training accuracy: 0.578231
#  test accuracy: 0.362637
# ----------------------------
# epoch_no : 12
# ------------------------
#  training accuracy: 0.585034
#  test accuracy: 0.406593
# ----------------------------
# epoch_no : 13
# ------------------------
#  training accuracy: 0.591837
#  test accuracy: 0.395604
# ----------------------------
# epoch_no : 14
# ------------------------
#  training accuracy: 0.598639
#  test accuracy: 0.395604
# ----------------------------
# epoch_no : 15
# ------------------------
#  training accuracy: 0.607143
#  test accuracy: 0.417582
# ----------------------------
# epoch_no : 16
# ------------------------
#  training accuracy: 0.622449
#  test accuracy: 0.483516
# ----------------------------
# epoch_no : 17
# ------------------------
#  training accuracy: 0.639456
#  test accuracy: 0.494505
# ----------------------------
# epoch_no : 18
# ------------------------
#  training accuracy: 0.658163
#  test accuracy: 0.538462
# ----------------------------
# epoch_no : 19
# ------------------------
#  training accuracy: 0.688776
#  test accuracy: 0.56044
# ----------------------------
# epoch_no : 20
# ------------------------
#  training accuracy: 0.707483
#  test accuracy: 0.571429
# ----------------------------
# epoch_no : 21
# ------------------------
#  training accuracy: 0.732993
#  test accuracy: 0.604396
# ----------------------------
# epoch_no : 22
# ------------------------
#  training accuracy: 0.744898
#  test accuracy: 0.67033
# ----------------------------
# epoch_no : 23
# ------------------------
#  training accuracy: 0.767007
#  test accuracy: 0.703297
# ----------------------------
# epoch_no : 24
# ------------------------
#  training accuracy: 0.777211
#  test accuracy: 0.725275
# ----------------------------
# epoch_no : 25
# ------------------------
#  training accuracy: 0.780612
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 26
# ------------------------
#  training accuracy: 0.787415
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 27
# ------------------------
#  training accuracy: 0.790816
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 28
# ------------------------
#  training accuracy: 0.795918
#  test accuracy: 0.725275
# ----------------------------
# epoch_no : 29
# ------------------------
#  training accuracy: 0.79932
#  test accuracy: 0.725275
# ----------------------------
# epoch_no : 30
# ------------------------
#  training accuracy: 0.79932
#  test accuracy: 0.725275
# ----------------------------
# epoch_no : 31
# ------------------------
#  training accuracy: 0.80102
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 32
# ------------------------
#  training accuracy: 0.80102
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 33
# ------------------------
#  training accuracy: 0.802721
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 34
# ------------------------
#  training accuracy: 0.802721
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 35
# ------------------------
#  training accuracy: 0.802721
#  test accuracy: 0.747253
# ----------------------------
# epoch_no : 36
# ------------------------
#  training accuracy: 0.806122
#  test accuracy: 0.747253
# ----------------------------
# epoch_no : 37
# ------------------------
#  training accuracy: 0.809524
#  test accuracy: 0.747253
# ----------------------------
# epoch_no : 38
# ------------------------
#  training accuracy: 0.814626
#  test accuracy: 0.747253
# ----------------------------
# epoch_no : 39
# ------------------------
#  training accuracy: 0.819728
#  test accuracy: 0.747253
# ----------------------------
# epoch_no : 40
# ------------------------
#  training accuracy: 0.821429
#  test accuracy: 0.747253
# ----------------------------
# epoch_no : 41
# ------------------------
#  training accuracy: 0.828231
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 42
# ------------------------
#  training accuracy: 0.835034
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 43
# ------------------------
#  training accuracy: 0.833333
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 44
# ------------------------
#  training accuracy: 0.840136
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 45
# ------------------------
#  training accuracy: 0.845238
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 46
# ------------------------
#  training accuracy: 0.841837
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 47
# ------------------------
#  training accuracy: 0.841837
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 48
# ------------------------
#  training accuracy: 0.840136
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 49
# ------------------------
#  training accuracy: 0.843537
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 50
# ------------------------
#  training accuracy: 0.845238
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 51
# ------------------------
#  training accuracy: 0.848639
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 52
# ------------------------
#  training accuracy: 0.85034
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 53
# ------------------------
#  training accuracy: 0.85034
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 54
# ------------------------
#  training accuracy: 0.853741
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 55
# ------------------------
#  training accuracy: 0.855442
#  test accuracy: 0.725275
# ----------------------------
# epoch_no : 56
# ------------------------
#  training accuracy: 0.855442
#  test accuracy: 0.747253
# ----------------------------
# epoch_no : 57
# ------------------------
#  training accuracy: 0.857143
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 58
# ------------------------
#  training accuracy: 0.863946
#  test accuracy: 0.758242
# ----------------------------
# epoch_no : 59
# ------------------------
#  training accuracy: 0.860544
#  test accuracy: 0.758242
# ----------------------------
# epoch_no : 60
# ------------------------
#  training accuracy: 0.863946
#  test accuracy: 0.747253
# ----------------------------
# epoch_no : 61
# ------------------------
#  training accuracy: 0.865646
#  test accuracy: 0.758242
# ----------------------------
# epoch_no : 62
# ------------------------
#  training accuracy: 0.870748
#  test accuracy: 0.747253
# ----------------------------
# epoch_no : 63
# ------------------------
#  training accuracy: 0.87415
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 64
# ------------------------
#  training accuracy: 0.880952
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 65
# ------------------------
#  training accuracy: 0.879252
#  test accuracy: 0.747253
# ----------------------------
# epoch_no : 66
# ------------------------
#  training accuracy: 0.879252
#  test accuracy: 0.747253
# ----------------------------
# epoch_no : 67
# ------------------------
#  training accuracy: 0.889456
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 68
# ------------------------
#  training accuracy: 0.887755
#  test accuracy: 0.725275
# ----------------------------
# epoch_no : 69
# ------------------------
#  training accuracy: 0.892857
#  test accuracy: 0.714286
# ----------------------------
# epoch_no : 70
# ------------------------
#  training accuracy: 0.894558
#  test accuracy: 0.78022
# ----------------------------
# epoch_no : 71
# ------------------------
#  training accuracy: 0.903061
#  test accuracy: 0.725275
# ----------------------------
# epoch_no : 72
# ------------------------
#  training accuracy: 0.914966
#  test accuracy: 0.747253
# ----------------------------
# epoch_no : 73
# ------------------------
#  training accuracy: 0.908163
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 74
# ------------------------
#  training accuracy: 0.914966
#  test accuracy: 0.714286
# ----------------------------
# epoch_no : 75
# ------------------------
#  training accuracy: 0.904762
#  test accuracy: 0.736264
# ----------------------------
# epoch_no : 76
# ------------------------
#  training accuracy: 0.894558
#  test accuracy: 0.758242
# ----------------------------
# epoch_no : 77
# ------------------------
#  training accuracy: 0.908163
#  test accuracy: 0.791209
# ----------------------------
# epoch_no : 78
# ------------------------
#  training accuracy: 0.911565
#  test accuracy: 0.78022
# ----------------------------
# epoch_no : 79
# ------------------------
#  training accuracy: 0.906463
#  test accuracy: 0.769231
# ----------------------------
# epoch_no : 80
# ------------------------
#  training accuracy: 0.909864
#  test accuracy: 0.758242
# ----------------------------
# epoch_no : 81
# ------------------------
#  training accuracy: 0.920068
#  test accuracy: 0.78022
# ----------------------------
# epoch_no : 82
# ------------------------
#  training accuracy: 0.916667
#  test accuracy: 0.802198
# ----------------------------
# epoch_no : 83
# ------------------------
#  training accuracy: 0.931973
#  test accuracy: 0.78022
# ----------------------------
# epoch_no : 84
# ------------------------
#  training accuracy: 0.937075
#  test accuracy: 0.769231
# ----------------------------
# epoch_no : 85
# ------------------------
#  training accuracy: 0.935374
#  test accuracy: 0.802198
# ----------------------------
# epoch_no : 86
# ------------------------
#  training accuracy: 0.940476
#  test accuracy: 0.791209
# ----------------------------
# epoch_no : 87
# ------------------------
#  training accuracy: 0.937075
#  test accuracy: 0.802198
# ----------------------------
# epoch_no : 88
# ------------------------
#  training accuracy: 0.943878
#  test accuracy: 0.791209
# ----------------------------
# epoch_no : 89
# ------------------------
#  training accuracy: 0.943878
#  test accuracy: 0.791209
# ----------------------------
# epoch_no : 90
# ------------------------
#  training accuracy: 0.947279
#  test accuracy: 0.791209
# ----------------------------
# epoch_no : 91
# ------------------------
#  training accuracy: 0.94898
#  test accuracy: 0.813187
# ----------------------------
# epoch_no : 92
# ------------------------
#  training accuracy: 0.959184
#  test accuracy: 0.791209
# ----------------------------
# epoch_no : 93
# ------------------------
#  training accuracy: 0.959184
#  test accuracy: 0.769231
# ----------------------------
# epoch_no : 94
# ------------------------
#  training accuracy: 0.964286
#  test accuracy: 0.78022
# ----------------------------
# epoch_no : 95
# ------------------------
#  training accuracy: 0.964286
#  test accuracy: 0.769231
# ----------------------------
# epoch_no : 96
# ------------------------
#  training accuracy: 0.969388
#  test accuracy: 0.769231
# ----------------------------
# epoch_no : 97
# ------------------------
#  training accuracy: 0.967687
#  test accuracy: 0.802198
# ----------------------------
# epoch_no : 98
# ------------------------
#  training accuracy: 0.969388
#  test accuracy: 0.791209
# ----------------------------
# epoch_no : 99
# ------------------------
#  training accuracy: 0.97619
#  test accuracy: 0.78022
# ----------------------------
